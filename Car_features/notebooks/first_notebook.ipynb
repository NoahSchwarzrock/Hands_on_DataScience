# %% [markdown]
# # Start

# %%
import pandas as pd

# %%
import sys
sys.path.append("..")

from scripts.helper_funcs import get_encoding

# %%
loc = "../data/raw/data.csv"

encoding = get_encoding(loc)

print(encoding)
# Out:
# ascii

# %%
df = pd.read_csv(loc)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df = df.rename(columns={"Make": "make", "Model": "model", "Year": "year","Engine Fuel Type": "engine_fuel_type", "Engine HP": "engine_hp", "Engine Cylinders": "engine_cylinders", "Transmission Type": "transmission_type", "Driven_Wheels": "driven_wheels", "Number of Doors": "number_of_doors", "Market Category": "market_category", "Vehicle Size": "vehicle_size", "Vehicle Style": "vehicle_style", "highway MPG": "highway_mpg", "city mpg": "city_mpg", "Popularity": "popularity", "MSRP": "msrp"})
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# # Identifiying duplicates

# %%
df[df.duplicated()]
# Out:
#          make     model  year             engine_fuel_type  engine_hp  \
# 14        BMW  1 Series  2013  premium unleaded (required)      230.0
# 18       Audi       100  1992             regular unleaded      172.0
# 20       Audi       100  1992             regular unleaded      172.0
# 24       Audi       100  1993             regular unleaded      172.0
# 25       Audi       100  1993             regular unleaded      172.0
# ...       ...       ...   ...                          ...        ...
# 11481  Suzuki      X-90  1998             regular unleaded       95.0
# 11603   Volvo      XC60  2017             regular unleaded      302.0
# 11604   Volvo      XC60  2017             regular unleaded      240.0
# 11708  Suzuki       XL7  2008             regular unleaded      252.0
# 11717  Suzuki       XL7  2008             regular unleaded      252.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# ...

# %%
df[df.duplicated()].isna().sum()
# Out:
# make                   0
# model                  0
# year                   0
# engine_fuel_type       0
# engine_hp              0
# engine_cylinders       0
# transmission_type      0
# driven_wheels          0
# number_of_doors        0
# market_category      366
# vehicle_size           0
# vehicle_style          0
# highway_mpg            0
# city_mpg               0
# popularity             0
# msrp                   0
# dtype: int64

# %% [markdown]
# ## Missing Values
#
# - engine_fuel_type 3
# - engine_hp 69
# - engine_cylinders 30
# - market_category 3742
#
# ## Duplicates
#
# - 715 rows × 16 columns

# %%
df_no_duplicates = df.drop_duplicates()

# %%
df_no_duplicates["engine_cylinders"].unique()
# Out:
# array([ 6.,  4.,  5.,  8., 12.,  0., nan, 10.,  3., 16.])

# %%
df_no_duplicates[df_no_duplicates["engine_cylinders"].isna()]
# Out:
#             make    model  year             engine_fuel_type  engine_hp  \
# 1983   Chevrolet  Bolt EV  2017                     electric      200.0
# 1984   Chevrolet  Bolt EV  2017                     electric      200.0
# 3716  Volkswagen   e-Golf  2015                     electric      115.0
# 3717  Volkswagen   e-Golf  2015                     electric      115.0
# 3718  Volkswagen   e-Golf  2016                     electric      115.0
# 3719  Volkswagen   e-Golf  2016                     electric      115.0
# 5778  Mitsubishi   i-MiEV  2014                     electric        NaN
# 5779  Mitsubishi   i-MiEV  2016                     electric       66.0
# 5780  Mitsubishi   i-MiEV  2017                     electric       66.0
# 8373      Toyota  RAV4 EV  2012                     electric      154.0
# 8695       Mazda     RX-7  1993             regular unleaded      255.0
# 8696       Mazda     RX-7  1994             regular unleaded      255.0
# ...

# %%
df_no_duplicates[df_no_duplicates["engine_cylinders"] == 0].groupby(["engine_fuel_type"]).count()
# Out:
#                   make  model  year  engine_hp  engine_cylinders  \
# engine_fuel_type
# electric            56     56    56         13                56
#
#                   transmission_type  driven_wheels  number_of_doors  \
# engine_fuel_type
# electric                         56             56               51
#
#                   market_category  vehicle_size  vehicle_style  highway_mpg  \
# engine_fuel_type
# electric                       51            56             56           56
#
#                   city_mpg  popularity  msrp
# engine_fuel_type
# electric                56          56    56

# %%
df_no_duplicates[df_no_duplicates["engine_cylinders"].isna()].groupby(["engine_fuel_type"]).count()
# Out:
#                              make  model  year  engine_hp  engine_cylinders  \
# engine_fuel_type
# electric                       10     10    10          9                 0
# premium unleaded (required)    17     17    17         17                 0
# regular unleaded                3      3     3          3                 0
#
#                              transmission_type  driven_wheels  \
# engine_fuel_type
# electric                                    10             10
# premium unleaded (required)                 17             17
# regular unleaded                             3              3
#
#                              number_of_doors  market_category  vehicle_size  \
# engine_fuel_type
# electric                                  10               10            10
# premium unleaded (required)               17               17            17
# regular unleaded                           3                3             3
#
# ...

# %% [markdown]
# ## I decided to transform the engine_cylinders from the electric vehicles to NaN

# %%
df_no_duplicates.loc[df_no_duplicates["engine_cylinders"] == 0, "engine_cylinders"] = None

# %%
df_no_duplicates[df_no_duplicates["engine_cylinders"] == 0]
# Out:
# Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []

# %% [markdown]
# ## fill the missing values on the column "engine_fuel_type"

# %%
df_no_duplicates[df_no_duplicates["engine_fuel_type"].isna()]
# Out:
#          make   model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 11321  Suzuki  Verona  2004              NaN      155.0               6.0
# 11322  Suzuki  Verona  2004              NaN      155.0               6.0
# 11323  Suzuki  Verona  2004              NaN      155.0               6.0
#
#       transmission_type      driven_wheels  number_of_doors market_category  \
# 11321         AUTOMATIC  front wheel drive              4.0             NaN
# 11322         AUTOMATIC  front wheel drive              4.0             NaN
# 11323         AUTOMATIC  front wheel drive              4.0             NaN
#
#       vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 11321      Midsize         Sedan           25        17         481  17199
# 11322      Midsize         Sedan           25        17         481  20199
# 11323      Midsize         Sedan           25        17         481  18499

# %%
df_no_duplicates[df_no_duplicates["model"] == "Verona"]
# Out:
#          make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 11321  Suzuki  Verona  2004               NaN      155.0               6.0
# 11322  Suzuki  Verona  2004               NaN      155.0               6.0
# 11323  Suzuki  Verona  2004               NaN      155.0               6.0
# 11324  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11325  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11326  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11327  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11328  Suzuki  Verona  2006  regular unleaded      155.0               6.0
# 11329  Suzuki  Verona  2006  regular unleaded      155.0               6.0
#
#       transmission_type      driven_wheels  number_of_doors market_category  \
# 11321         AUTOMATIC  front wheel drive              4.0             NaN
# ...

# %% [markdown]
# ### setting the values to regular unleaded, imputate the missing values through infos of the dataset and domain knowledge

# %%
df_no_duplicates.loc[df_no_duplicates["engine_fuel_type"].isna(), "engine_fuel_type"] = "regular unleaded"
df_no_duplicates[df_no_duplicates["model"] == "Verona"]
# Out:
#          make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 11321  Suzuki  Verona  2004  regular unleaded      155.0               6.0
# 11322  Suzuki  Verona  2004  regular unleaded      155.0               6.0
# 11323  Suzuki  Verona  2004  regular unleaded      155.0               6.0
# 11324  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11325  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11326  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11327  Suzuki  Verona  2005  regular unleaded      155.0               6.0
# 11328  Suzuki  Verona  2006  regular unleaded      155.0               6.0
# 11329  Suzuki  Verona  2006  regular unleaded      155.0               6.0
#
#       transmission_type      driven_wheels  number_of_doors market_category  \
# 11321         AUTOMATIC  front wheel drive              4.0             NaN
# ...

# %% [markdown]
# ## fill missing values of column "number of doors"

# %%
df_no_duplicates[df_no_duplicates["number_of_doors"].isna()]
# Out:
#          make    model  year             engine_fuel_type  engine_hp  \
# 4666  Ferrari       FF  2013  premium unleaded (required)      651.0
# 6930    Tesla  Model S  2016                     electric        NaN
# 6931    Tesla  Model S  2016                     electric        NaN
# 6932    Tesla  Model S  2016                     electric        NaN
# 6933    Tesla  Model S  2016                     electric        NaN
# 6934    Tesla  Model S  2016                     electric        NaN
#
#       engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 4666              12.0  AUTOMATED_MANUAL   all wheel drive              NaN
# 6930               NaN      DIRECT_DRIVE   all wheel drive              NaN
# 6931               NaN      DIRECT_DRIVE   all wheel drive              NaN
# 6932               NaN      DIRECT_DRIVE   all wheel drive              NaN
# 6933               NaN      DIRECT_DRIVE  rear wheel drive              NaN
# ...

# %%
df_no_duplicates[(df_no_duplicates["model"] == "FF") | (df_no_duplicates["model"] == "Model S")]
# Out:
#          make    model  year             engine_fuel_type  engine_hp  \
# 4666  Ferrari       FF  2013  premium unleaded (required)      651.0
# 4667  Ferrari       FF  2014  premium unleaded (required)      651.0
# 4668  Ferrari       FF  2015  premium unleaded (required)      651.0
# 6921    Tesla  Model S  2014                     electric        NaN
# 6922    Tesla  Model S  2014                     electric        NaN
# 6923    Tesla  Model S  2014                     electric        NaN
# 6924    Tesla  Model S  2014                     electric        NaN
# 6925    Tesla  Model S  2015                     electric        NaN
# 6926    Tesla  Model S  2015                     electric        NaN
# 6927    Tesla  Model S  2015                     electric        NaN
# 6928    Tesla  Model S  2015                     electric        NaN
# 6929    Tesla  Model S  2015                     electric        NaN
# 6930    Tesla  Model S  2016                     electric        NaN
# ...

# %%
df_no_duplicates.loc[
    (df_no_duplicates["model"] == "Model S") & (df_no_duplicates["number_of_doors"].isna()), 
    "number_of_doors"
] = 4

# %%
df_no_duplicates.loc[
    (df_no_duplicates["model"] == "FF") & (df_no_duplicates["number_of_doors"].isna()),
    "number_of_doors"
    ] = 2

# %%
df_no_duplicates[(df_no_duplicates["model"] == "FF") | (df_no_duplicates["model"] == "Model S")]
# Out:
#          make    model  year             engine_fuel_type  engine_hp  \
# 4666  Ferrari       FF  2013  premium unleaded (required)      651.0
# 4667  Ferrari       FF  2014  premium unleaded (required)      651.0
# 4668  Ferrari       FF  2015  premium unleaded (required)      651.0
# 6921    Tesla  Model S  2014                     electric        NaN
# 6922    Tesla  Model S  2014                     electric        NaN
# 6923    Tesla  Model S  2014                     electric        NaN
# 6924    Tesla  Model S  2014                     electric        NaN
# 6925    Tesla  Model S  2015                     electric        NaN
# 6926    Tesla  Model S  2015                     electric        NaN
# 6927    Tesla  Model S  2015                     electric        NaN
# 6928    Tesla  Model S  2015                     electric        NaN
# 6929    Tesla  Model S  2015                     electric        NaN
# 6930    Tesla  Model S  2016                     electric        NaN
# ...
