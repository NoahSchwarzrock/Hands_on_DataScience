# %%
import pandas as pd

df = pd.read_csv("data/BFw_mission_data_daily.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2570 entries, 0 to 2569
# Data columns (total 25 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   mission_created_date                            2570 non-null   object
#  1   mission_count_all                               2570 non-null   object
#  2   mission_count_ems                               2570 non-null   object
#  3   mission_count_ems_critical                      2570 non-null   object
#  4   mission_count_ems_critical_cpr                  2570 non-null   object
#  5   mission_count_fire                              2570 non-null   object
#  6   mission_count_technical_rescue                  2570 non-null   object
#  7   response_time_ems_critical_mean                 2570 non-null   object
#  8   response_time_ems_critical_median               2570 non-null   object
# ...

# %%
df
# Out:
#       mission_created_date  mission_count_all  mission_count_ems  \
# 0               2018-01-01               2229               1781
# 1               2018-01-02               1241               1165
# 2               2018-01-03               1355               1280
# 3               2018-01-04               1308               1243
# 4               2018-01-05               1269               1197
# ...                    ...                ...                ...
# 2565            2025-01-11               1468               1341
# 2566            2025-01-12               1399               1275
# 2567            2025-01-13               1555               1392
# 2568            2025-01-14               1502               1355
# 2569  mission_created_date  mission_count_all  mission_count_ems
#
#       mission_count_ems_critical  mission_count_ems_critical_cpr  \
# 0                           1019                              22
# ...

# %%
df = df.set_index("mission_created_date")

# %%
df.index.dtype
# Out:
# dtype('O')
